# %% [markdown]
# # Title of the Assignment: Descriptive Statistics - Measures of Central Tendency and variability

# %% [markdown]
# Perform the following operations on any open source dataset (e.g., data.csv)
# 1. Provide summary statistics (mean, median, minimum, maximum, standard deviation) for a
# dataset (age, income etc.) with numeric variables grouped by one of the qualitative
# (categorical) variables. For example, if your categorical variable is age groups and
# quantitative variable is income, then provide summary statistics of income grouped by the age
# groups. Create a list that contains a numeric value for each response to the categorical
# variable.
# 2. Write a Python program to display some basic statistical details like percentile, mean,
# standard deviation etc. of the species of ‘Iris-setosa’, ‘Iris-versicolor’ and ‘Iris- versicolor’ of
# iris.csv dataset.

# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# # 1

# %%
df=pd.read_csv("Customer.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre   Age Group  Age  Annual Income (k$)  \
# 0           1    Male        Teen   19                  15
# 1           2    Male  Middle Age   21                  15
# 2           3  Female  Middle Age   20                  16
# 3           4  Female  Middle Age   23                  16
# 4           5  Female  Middle Age   31                  17
#
#    Spending Score (1-100)
# 0                      39
# 1                      81
# 2                       6
# 3                      77
# 4                      40

# %%
df.tail()
# Out:
#      CustomerID   Genre   Age Group  Age  Annual Income (k$)  \
# 195         196  Female  Middle Age   35                 120
# 196         197  Female       Elder   45                 126
# 197         198    Male  Middle Age   32                 126
# 198         199    Male  Middle Age   32                 132
# 199         200    Male  Middle Age   30                 137
#
#      Spending Score (1-100)
# 195                      79
# 196                      28
# 197                      74
# 198                      18
# 199                      83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age Group               200 non-null    object
#  3   Age                     200 non-null    int64
#  4   Annual Income (k$)      200 non-null    int64
#  5   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 9.5+ KB

# %%
df.shape
# Out:
# (200, 6)

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      CustomerID   Genre   Age Group  Age  Annual Income (k$)  \
# 0             1    Male        Teen   19                  15
# 1             2    Male  Middle Age   21                  15
# 2             3  Female  Middle Age   20                  16
# 3             4  Female  Middle Age   23                  16
# 4             5  Female  Middle Age   31                  17
# ..          ...     ...         ...  ...                 ...
# 195         196  Female  Middle Age   35                 120
# 196         197  Female       Elder   45                 126
# 197         198    Male  Middle Age   32                 126
# 198         199    Male  Middle Age   32                 132
# 199         200    Male  Middle Age   30                 137
#
#      Spending Score (1-100)
# 0                        39
# 1                        81
# 2                         6
# 3                        77
# 4                        40
# ..                      ...
# 195                      79
# 196                      28
# 197                      74
# 198                      18
# 199                      83
#
# [200 rows x 6 columns]>

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   56.650000           70.865000               52.265000
# std     57.879185   19.027816           30.424415               26.805549
# min      1.000000   18.000000           15.000000                6.000000
# 25%     50.750000   41.750000           47.750000               34.000000
# 50%    100.500000   58.000000           67.000000               56.000000
# 75%    150.250000   72.250000           89.000000               78.000000
# max    200.000000   92.000000          137.000000               90.000000

# %%
df.Age.mean()
# Out:
# 56.65

# %%
df.Age.mode()
# Out:
# 0    32
# 1    45
# Name: Age, dtype: int64

# %%
df.Age.median()
# Out:
# 58.0

# %%
df.groupby(['Age']).count()
# Out:
#      CustomerID  Genre  Age Group  Annual Income (k$)  Spending Score (1-100)
# Age
# 18            1      1          1                   1                       1
# 19            2      2          2                   2                       2
# 20            1      1          1                   1                       1
# 21            1      1          1                   1                       1
# 22            1      1          1                   1                       1
# ..          ...    ...        ...                 ...                     ...
# 88            2      2          2                   2                       2
# 89            1      1          1                   1                       1
# 90            2      2          2                   2                       2
# 91            1      1          1                   1                       1
# 92            1      1          1                   1                       1
#
# [75 rows x 5 columns]

# %%
df.groupby(['Genre']).count()
# Out:
#         CustomerID  Age Group  Age  Annual Income (k$)  Spending Score (1-100)
# Genre
# Female         100        100  100                 100                     100
# Male           100        100  100                 100                     100

# %%
df.Age.std()
# Out:
# 19.027816189587387

# %%
df[['Age' , 'Annual Income (k$)', 'Spending Score (1-100)']].mean()
# Out:
# Age                       56.650
# Annual Income (k$)        70.865
# Spending Score (1-100)    52.265
# dtype: float64

# %%
df[['Age' , 'Annual Income (k$)', 'Spending Score (1-100)']].mode()
# Out:
#     Age  Annual Income (k$)  Spending Score (1-100)
# 0  32.0                  45                    34.0
# 1  45.0                  56                     NaN
# 2   NaN                  67                     NaN

# %%
df[['Age' , 'Annual Income (k$)', 'Spending Score (1-100)']].median()
# Out:
# Age                       58.0
# Annual Income (k$)        67.0
# Spending Score (1-100)    56.0
# dtype: float64

# %%
df[['Age' , 'Annual Income (k$)', 'Spending Score (1-100)']].max()
# Out:
# Age                        92
# Annual Income (k$)        137
# Spending Score (1-100)     90
# dtype: int64

# %%
df[['Age' , 'Annual Income (k$)', 'Spending Score (1-100)']].std()
# Out:
# Age                       19.027816
# Annual Income (k$)        30.424415
# Spending Score (1-100)    26.805549
# dtype: float64

# %%
df2 = df.groupby('Genre')

# %%
df
# Out:
#      CustomerID   Genre   Age Group  Age  Annual Income (k$)  \
# 0             1    Male        Teen   19                  15
# 1             2    Male  Middle Age   21                  15
# 2             3  Female  Middle Age   20                  16
# 3             4  Female  Middle Age   23                  16
# 4             5  Female  Middle Age   31                  17
# ..          ...     ...         ...  ...                 ...
# 195         196  Female  Middle Age   35                 120
# 196         197  Female       Elder   45                 126
# 197         198    Male  Middle Age   32                 126
# 198         199    Male  Middle Age   32                 132
# 199         200    Male  Middle Age   30                 137
#
#      Spending Score (1-100)
# 0                        39
# 1                        81
# 2                         6
# 3                        77
# 4                        40
# ..                      ...
# 195                      79
# 196                      28
# 197                      74
# 198                      18
# 199                      83
#
# [200 rows x 6 columns]

# %%
for Genre, Genre_f in df2:
    print(Genre)
    print(Genre_f)
# Out:
# Female
#      CustomerID   Genre    Age Group  Age  Annual Income (k$)  \
# 2             3  Female   Middle Age   20                  16
# 3             4  Female   Middle Age   23                  16
# 4             5  Female   Middle Age   31                  17
# 5             6  Female  Young Adult   25                  45
# 7             8  Female  Young Adult   22                  34
# ..          ...     ...          ...  ...                 ...
# 190         191  Female   Middle Age   46                 126
# 192         193  Female  Young Adult   47                 127
# 194         195  Female   Middle Age   64                 128
# 195         196  Female   Middle Age   35                 120
# 196         197  Female        Elder   45                 126
#
#      Spending Score (1-100)
# 2                         6
# 3                        77
# 4                        40
# 5                        65
# 7                        76
# ..                      ...
# 190                      67
# 192                      23
# 194                      34
# 195                      79
# 196                      28
#
# [100 rows x 6 columns]
# Male
#      CustomerID Genre   Age Group  Age  Annual Income (k$)  \
# 0             1  Male        Teen   19                  15
# 1             2  Male  Middle Age   21                  15
# 6             7  Male  Middle Age   35                  78
# 8             9  Male        Teen   19                  56
# 10           11  Male  Middle Age   38                  67
# ..          ...   ...         ...  ...                 ...
# 191         192  Male  Middle Age   86                  42
# 193         194  Male  Middle Age   76                  56
# 197         198  Male  Middle Age   32                 126
# 198         199  Male  Middle Age   32                 132
# 199         200  Male  Middle Age   30                 137
#
#      Spending Score (1-100)
# 0                        39
# 1                        81
# 6                        23
# 8                        12
# 10                       89
# ..                      ...
# 191                      89
# 193                      56
# 197                      74
# 198                      18
# 199                      83
#
# [100 rows x 6 columns]

# %%
df2.get_group('Male')
# Out:
#      CustomerID Genre   Age Group  Age  Annual Income (k$)  \
# 0             1  Male        Teen   19                  15
# 1             2  Male  Middle Age   21                  15
# 6             7  Male  Middle Age   35                  78
# 8             9  Male        Teen   19                  56
# 10           11  Male  Middle Age   38                  67
# ..          ...   ...         ...  ...                 ...
# 191         192  Male  Middle Age   86                  42
# 193         194  Male  Middle Age   76                  56
# 197         198  Male  Middle Age   32                 126
# 198         199  Male  Middle Age   32                 132
# 199         200  Male  Middle Age   30                 137
#
#      Spending Score (1-100)
# 0                        39
# 1                        81
# 6                        23
# 8                        12
# 10                       89
# ..                      ...
# 191                      89
# 193                      56
# 197                      74
# 198                      18
# 199                      83
#
# [100 rows x 6 columns]

# %%
df2.get_group('Female')
# Out:
#      CustomerID   Genre    Age Group  Age  Annual Income (k$)  \
# 2             3  Female   Middle Age   20                  16
# 3             4  Female   Middle Age   23                  16
# 4             5  Female   Middle Age   31                  17
# 5             6  Female  Young Adult   25                  45
# 7             8  Female  Young Adult   22                  34
# ..          ...     ...          ...  ...                 ...
# 190         191  Female   Middle Age   46                 126
# 192         193  Female  Young Adult   47                 127
# 194         195  Female   Middle Age   64                 128
# 195         196  Female   Middle Age   35                 120
# 196         197  Female        Elder   45                 126
#
#      Spending Score (1-100)
# 2                         6
# 3                        77
# 4                        40
# 5                        65
# 7                        76
# ..                      ...
# 190                      67
# 192                      23
# 194                      34
# 195                      79
# 196                      28
#
# [100 rows x 6 columns]

# %%
df2[['Age' , 'Annual Income (k$)', 'Spending Score (1-100)']].median()
# Out:
#          Age  Annual Income (k$)  Spending Score (1-100)
# Genre
# Female  52.0                78.0                    56.0
# Male    63.5                64.5                    56.0

# %%
df2[['Age' , 'Annual Income (k$)', 'Spending Score (1-100)']].mean()
# Out:
#          Age  Annual Income (k$)  Spending Score (1-100)
# Genre
# Female  53.9               75.24                   52.30
# Male    59.4               66.49                   52.23

# %%
df2[['Age' , 'Annual Income (k$)', 'Spending Score (1-100)']].max()
# Out:
#         Age  Annual Income (k$)  Spending Score (1-100)
# Genre
# Female   91                 128                      90
# Male     92                 137                      90

# %%
df2[['Age' , 'Annual Income (k$)', 'Spending Score (1-100)']].min()
# Out:
#         Age  Annual Income (k$)  Spending Score (1-100)
# Genre
# Female   18                  16                       6
# Male     19                  15                      12

# %%
df2[['Age' , 'Annual Income (k$)', 'Spending Score (1-100)']].std()
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# Genre
# Female  18.421277           32.654024               25.719348
# Male    19.317130           27.489758               27.979377

# %% [markdown]
# # 2

# %%
df2=pd.read_csv("Iris.csv")

# %%
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df2.columns=("A" , "B" , " C " , "D" , "E","F")

# %%
df2
# Out:
#        A    B   C     D    E               F
# 0      1  5.1  3.5  1.4  0.2     Iris-setosa
# 1      2  4.9  3.0  1.4  0.2     Iris-setosa
# 2      3  4.7  3.2  1.3  0.2     Iris-setosa
# 3      4  4.6  3.1  1.5  0.2     Iris-setosa
# 4      5  5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...  ...             ...
# 145  146  6.7  3.0  5.2  2.3  Iris-virginica
# 146  147  6.3  2.5  5.0  1.9  Iris-virginica
# 147  148  6.5  3.0  5.2  2.0  Iris-virginica
# 148  149  6.2  3.4  5.4  2.3  Iris-virginica
# 149  150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
